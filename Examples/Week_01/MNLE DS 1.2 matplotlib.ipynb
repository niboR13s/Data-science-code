# %% [markdown]
# # 1. MATPLOTLIB LINE PLOT

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Generate a list (10 values between 1 and 100) and do a simple plot
data_list = np.random.randint(low=1, high=100, size=10)
data_list
# Out:
# array([21, 56, 74, 74, 54, 75, 63, 20, 54, 73])

# %%
plt.plot(data_list)

# %%
# Read the stock prices data using pandas
# It contains the value of 9 stocks for 2159 days (2012-2020)
stock_df = pd.read_csv('/content/drive/My Drive/Datasets/stocks.csv')
stock_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Read the stock prices data using pandas
#       2 # It contains the value of 9 stocks for 2159 days (2012-2020)
# ----> 3 stock_df = pd.read_csv('/content/drive/My Drive/Datasets/stocks.csv')
#       4 stock_df
#
# ...

# %%
# Apple stock value
stock_df.plot(x = 'Date', y = 'AAPL', label = 'APPLE Stock Price', linewidth = 3)
# Out:
# <Axes: xlabel='Date'>

# %%
stock_df.plot(x = 'Date', y = 'AAPL', label = 'APPLE Stock Price', linewidth = 3)
plt.ylabel('Price')
plt.title('My first plotting exercise!')
plt.legend(loc="upper left")
plt.grid()

# %%
# Google stock value, line in red color
stock_df.plot(x = 'Date', y = 'GOOG', label = 'Google Stock Price', color = 'r', linewidth = 3)
plt.ylabel('Price')
plt.title('My first plotting exercise!')
plt.legend(loc="upper left")
plt.grid()

# %% [markdown]
# # 2. SCATTERPLOT

# %%
# Read daily return data using pandas
# Daily return is the stock value change in % on a per day basis

daily_return_df = pd.read_csv('/content/drive/My Drive/Datasets/daily_returns.csv')
daily_return_df
# Out:
#           AAPL     sp500      GOOG
# 0     0.000000  0.000000  0.000000
# 1    -0.374946 -0.494792 -0.738516
# 2     1.164812  0.355295  0.574410
# 3     1.038382  1.110793  0.688856
# 4    -0.316937  0.493866  1.052283
# ...        ...       ...       ...
# 2154  0.362467  0.642974  0.589774
# 2155  3.488923  0.642770  1.797626
# 2156 -2.449458  0.063303 -0.373974
# 2157  1.453480  0.274222  0.107728
# 2158 -2.973987 -0.796913 -1.054744
#
# [2159 rows x 3 columns]

# %%
# import random
# Compare the change in Apple stock against the change in S&P 500 value

X = daily_return_df['AAPL']
Y = daily_return_df['sp500']

plt.scatter(X, Y)

# %%
# Add x and y labels
plt.xlabel('Apple daily returns')
plt.ylabel('S&P500 daily returns')
plt.scatter(X, Y)

# %% [markdown]
# # 3. PIE CHART

# %%
values  = [20, 55, 5, 17, 3]
colors  = ['g', 'r', 'y', 'b', 'm']
# emphasis on certain slices
explode = [0, 0, 0, 0, 0.2]
labels  = ['AAPL', 'GOOG', 'T', 'TSLA', 'AMZN']

# Use matplotlib to plot a pie chart
plt.figure(figsize = (7, 7))
plt.pie(values, colors = colors, labels = labels, explode = explode)
plt.title('STOCK PORTFOLIO')
plt.show()

# %% [markdown]
# # 4. HISTOGRAMS

# %%
# A histogram represents data using bars of various heights.
# Each bar groups numbers into specific ranges.
# Taller bars show that more data falls within that specific range.


mu = daily_return_df['AAPL'].mean() # mean of distribution
sigma = daily_return_df['AAPL'].std() # standard deviation of distribution

print('mu = ', mu)
print('sigma = ', sigma)
# Out:
# mu =  0.10769549437154666
# sigma =  1.7757676749017137

# %%
num_bins = 40

# Plot the histogram of the returns
plt.figure(figsize = (7, 5))
plt.hist(daily_return_df['AAPL'], num_bins, facecolor = 'blue');
plt.grid()
plt.ylabel('Probability')
plt.title('Histogram: mu=' + str(mu) + ', sigma=' + str(sigma));

# %% [markdown]
# # 5. MULTIPLE PLOTS

# %%
stock_df
# Out:
#             Date        AAPL          BA          T        MGM         AMZN  \
# 0     2012-01-12   60.198570   75.510002  30.120001  12.130000   175.929993
# 1     2012-01-13   59.972858   74.599998  30.070000  12.350000   178.419998
# 2     2012-01-17   60.671429   75.239998  30.250000  12.250000   181.660004
# 3     2012-01-18   61.301430   75.059998  30.330000  12.730000   189.440002
# 4     2012-01-19   61.107143   75.559998  30.420000  12.800000   194.449997
# ...          ...         ...         ...        ...        ...          ...
# 2154  2020-08-05  440.250000  174.279999  29.850000  16.719999  3205.030029
# 2155  2020-08-06  455.609985  172.199997  29.840000  18.459999  3225.000000
# 2156  2020-08-07  444.450012  170.020004  30.020000  19.030001  3167.459961
# 2157  2020-08-10  450.910004  179.410004  30.200001  21.650000  3148.159912
# 2158  2020-08-11  437.500000  180.130005  30.200001  21.500000  3080.669922
#
#              IBM         TSLA         GOOG        sp500
# ...

# %%
# Plot 2 stocks in one plot
stock_df.plot(x = 'Date', y = ['AAPL', 'sp500'], linewidth = 3)
plt.ylabel('Price')
plt.title('Stock Prices')
plt.grid()

# %% [markdown]
# # 6. SUBPLOTS

# %%
# Plot 2 subplots into one plot with 1 row and 2 columns
plt.figure(figsize = (8, 5))

plt.subplot(1, 2, 1)
plt.plot(stock_df['AAPL'], 'r');
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(stock_df['sp500'], 'b');
plt.grid()

# %%
# Plot 2 subplots into one plot with 2 rows and 1 columns
plt.figure(figsize = (8, 8))

plt.subplot(2, 1, 1)
plt.plot(stock_df['AAPL'], 'r');
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(stock_df['sp500'], 'b');
plt.grid()

# %% [markdown]
# # 7. 3D PLOTS

# %%
# 3D scatterplot example
# Toolkits are collections of application-specific functions that extend Matplotlib.
# mpl_toolkits.mplot3d provides tools for basic 3D plotting.
# https://matplotlib.org/mpl_toolkits/index.html

from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

x = daily_return_df['AAPL'].tolist()
y = daily_return_df['sp500'].tolist()
z = daily_return_df['GOOG'].tolist()

ax.scatter(x, y, z, c = 'r', marker = 'o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5, 0, 'Z Label')

# %% [markdown]
# # 8. BOXPLOTS

# %%
# numpy.random.normal() takes three arguments: mean, standard deviation of the normal distribution, and number of values desired.
# Great resource for boxplots: https://stackoverflow.com/questions/17725927/boxplots-in-matplotlib-markers-and-outliers

np.random.seed(20)

data_1 = np.random.normal(200, 20, 2000)
data_2 = np.random.normal(60, 30, 2000)
data_3 = np.random.normal(70, 20, 2000)
data_4 = np.random.normal(40, 5, 2000)

data_all = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize = (10, 7))
ax = fig.add_subplot(111)
bp = ax.boxplot(data_all)
